# %%
import pandas as pd

# %%
df = pd.read_csv('data_GS.csv',index_col=0)
df.head()
# Out:
#                                                      Raw_GS  \
# Model     ['KNeighborsClassifier', 'LogisticRegression',...
# Accuracy  [0.9375, 0.9875, 0.87, 0.9825, 0.97, 0.925, 0....
# f1_micro  [0.9375, 0.9875, 0.87, 0.9825, 0.97, 0.925, 0....
# f1_macro  [0.9368485378224347, 0.9873720925474728, 0.868...
#
#                                              Feature_eng_GS  \
# Model     ['KNeighborsClassifier', 'LogisticRegression',...
# Accuracy  [0.425, 0.7825, 0.89, 0.9725, 0.98, 0.935, 0.8...
# f1_micro  [0.425, 0.7825, 0.89, 0.9725, 0.98, 0.935, 0.8...
# f1_macro  [0.4271099429889122, 0.7797464081634431, 0.889...
#
#                                      Feature_engg + Corr_GS  \
# Model     ['KNeighborsClassifier', 'LogisticRegression',...
# Accuracy  [0.435, 0.775, 0.895, 0.9775, 0.98, 0.9275, 0....
# f1_micro  [0.435, 0.775, 0.895, 0.9775, 0.98, 0.9275, 0....
# f1_macro  [0.43797780568361366, 0.7728893797308118, 0.89...
#
# ...

# %%
pd.DataFrame(df.unstack().unique()).iloc[1]
# Out:
# 0    [0.9375, 0.9875, 0.87, 0.9825, 0.97, 0.925, 0....
# Name: 1, dtype: object

# %%
df
# Out:
#                                                      Raw_GS  \
# Model     ['KNeighborsClassifier', 'LogisticRegression',...
# Accuracy  [0.9375, 0.9875, 0.87, 0.9825, 0.97, 0.925, 0....
# f1_micro  [0.9375, 0.9875, 0.87, 0.9825, 0.97, 0.925, 0....
# f1_macro  [0.9368485378224347, 0.9873720925474728, 0.868...
#
#                                              Feature_eng_GS  \
# Model     ['KNeighborsClassifier', 'LogisticRegression',...
# Accuracy  [0.425, 0.7825, 0.89, 0.9725, 0.98, 0.935, 0.8...
# f1_micro  [0.425, 0.7825, 0.89, 0.9725, 0.98, 0.935, 0.8...
# f1_macro  [0.4271099429889122, 0.7797464081634431, 0.889...
#
#                                      Feature_engg + Corr_GS  \
# Model     ['KNeighborsClassifier', 'LogisticRegression',...
# Accuracy  [0.435, 0.775, 0.895, 0.9775, 0.98, 0.9275, 0....
# f1_micro  [0.435, 0.775, 0.895, 0.9775, 0.98, 0.9275, 0....
# f1_macro  [0.43797780568361366, 0.7728893797308118, 0.89...
#
# ...
